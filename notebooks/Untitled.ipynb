# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/Team_Stats/2000-2019_cleaned_data3.csv")

# %%
df
# Out:
#      Year  Rk_Off                 Team  Win  Loss  Games  PF_Off  \
# 0    2000       1       St. Louis Rams   10     6     16     540
# 1    2000       2       Denver Broncos   11     5     16     485
# 2    2000       3      Oakland Raiders   12     4     16     479
# 3    2000       4   Indianapolis Colts   10     6     16     429
# 4    2000       5    Minnesota Vikings   11     5     16     397
# ..    ...     ...                  ...  ...   ...    ...     ...
# 633  2019      28       Denver Broncos    7     9     16     282
# 634  2019      29        Chicago Bears    8     8     16     280
# 635  2019      30   Cincinnati Bengals    2    14     16     279
# 636  2019      31        New York Jets    7     9     16     276
# 637  2019      32  Washington Redskins    3    13     16     266
#
#      Total Yds_Off  Plays_Off  Y/P_Off  ...  Pen_Def  Pen Yds_Def  1stPy_Def  \
# 0             7075       1014      7.0  ...      101          747         31
# ...

# %%
col_list = ["Year", "Team", "PPG_Off", "PPG_Def"]
ppg_df = df[col_list]
ppg_df
# Out:
#      Year                 Team  PPG_Off  PPG_Def
# 0    2000       St. Louis Rams  33.7500  29.4375
# 1    2000       Denver Broncos  30.3125  23.0625
# 2    2000      Oakland Raiders  29.9375  18.6875
# 3    2000   Indianapolis Colts  26.8125  20.3750
# 4    2000    Minnesota Vikings  24.8125  23.1875
# ..    ...                  ...      ...      ...
# 633  2019       Denver Broncos  17.6250  19.7500
# 634  2019        Chicago Bears  17.5000  18.6250
# 635  2019   Cincinnati Bengals  17.4375  26.2500
# 636  2019        New York Jets  17.2500  22.4375
# 637  2019  Washington Redskins  16.6250  27.1875
#
# [638 rows x 4 columns]

# %%
ppg_df.to_csv('../Data/Team_Stats/ppg_data.csv', index = False)
