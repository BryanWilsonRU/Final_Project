# %%
import pandas as pd

# %%
offense_2005 = pd.read_csv("../Team_Stats/2005_team_offense.csv")
defense_2005 = pd.read_csv("../Team_Stats/2005_team_defense.csv")
offense_2006 = pd.read_csv("../Team_Stats/2006_team_offense.csv")
defense_2006 = pd.read_csv("../Team_Stats/2006_team_defense.csv")
offense_2007 = pd.read_csv("../Team_Stats/2007_team_offense.csv")
defense_2007 = pd.read_csv("../Team_Stats/2007_team_defense.csv")
offense_2008 = pd.read_csv("../Team_Stats/2008_team_offense.csv")
defense_2008 = pd.read_csv("../Team_Stats/2008_team_defense.csv")
offense_2009 = pd.read_csv("../Team_Stats/2009_team_offense.csv")
defense_2009 = pd.read_csv("../Team_Stats/2009_team_defense.csv")

# %% [markdown]
# # 2005

# %%
df_2005 = offense_2005.merge(defense_2005, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2005.head()
# Out:
#    Year_Off  Rk_Off              Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2005       1    Seattle Seahawks       13         3     16     452
# 1      2005       2  Indianapolis Colts       14         2     16     439
# 2      2005       3     New York Giants       11         5     16     422
# 3      2005       4  Cincinnati Bengals       11         5     16     421
# 4      2005       5  San Diego Chargers        9         7     16     418
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5915       1020      5.8  ...          1510            5
# 1           5799       1000      5.8  ...          1762            9
# 2           5787       1055      5.5  ...          1656           12
# 3           5730       1018      5.6  ...          1850           16
# 4           5567       1022      5.4  ...          1349           14
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2005 = df_2005.drop('Year_Def', 1)
df_2005 = df_2005.drop('Win_Def', 1)
df_2005 = df_2005.drop('Loss_Def', 1) 
df_2005 = df_2005.drop('Tm_Def', 1)
df_2005 = df_2005.drop('G_Def', 1)
df_2005.head()
# Out:
#    Year_Off  Rk_Off              Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2005       1    Seattle Seahawks       13         3     16     452
# 1      2005       2  Indianapolis Colts       14         2     16     439
# 2      2005       3     New York Giants       11         5     16     422
# 3      2005       4  Cincinnati Bengals       11         5     16     421
# 4      2005       5  San Diego Chargers        9         7     16     418
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5915       1020      5.8  ...          1510            5
# 1           5799       1000      5.8  ...          1762            9
# 2           5787       1055      5.5  ...          1656           12
# 3           5730       1018      5.6  ...          1850           16
# 4           5567       1022      5.4  ...          1349           14
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2005 = df_2005.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2005.head()
# Out:
#    Year  Rk_Off                Team  Win  Loss  Games  PF_Off  Total Yds_Off  \
# 0  2005       1    Seattle Seahawks   13     3     16     452           5915
# 1  2005       2  Indianapolis Colts   14     2     16     439           5799
# 2  2005       3     New York Giants   11     5     16     422           5787
# 3  2005       4  Cincinnati Bengals   11     5     16     421           5730
# 4  2005       5  San Diego Chargers    9     7     16     418           5567
#
#    Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  Rush Y/A_Def  \
# 0       1020      5.8  ...          1510            5           3.6
# 1       1000      5.8  ...          1762            9           4.4
# 2       1055      5.5  ...          1656           12           3.9
# 3       1018      5.6  ...          1850           16           4.3
# 4       1022      5.4  ...          1349           14           3.5
#
#    Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  TO%_Def  EXP_Def
# ...

# %% [markdown]
# # 2006

# %%
df_2006 = offense_2006.merge(defense_2006, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2006.head()
# Out:
#    Year_Off  Rk_Off              Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2006       1  San Diego Chargers       14         2     16     492
# 1      2006       2       Chicago Bears       13         3     16     427
# 2      2006       3  Indianapolis Colts       12         4     16     427
# 3      2006       4      Dallas Cowboys        9         7     16     425
# 4      2006       5  New Orleans Saints       10         6     16     413
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5840       1016      5.7  ...          1613           13
# 1           5199       1042      5.0  ...          1590            7
# 2           6070       1011      6.0  ...          2768           20
# 3           5772       1015      5.7  ...          1659           12
# 4           6264       1075      5.8  ...          2063           10
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2006 = df_2006.drop('Year_Def', 1)
df_2006 = df_2006.drop('Win_Def', 1)
df_2006 = df_2006.drop('Loss_Def', 1) 
df_2006 = df_2006.drop('Tm_Def', 1)
df_2006 = df_2006.drop('G_Def', 1)
df_2006.head()
# Out:
#    Year_Off  Rk_Off              Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2006       1  San Diego Chargers       14         2     16     492
# 1      2006       2       Chicago Bears       13         3     16     427
# 2      2006       3  Indianapolis Colts       12         4     16     427
# 3      2006       4      Dallas Cowboys        9         7     16     425
# 4      2006       5  New Orleans Saints       10         6     16     413
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5840       1016      5.7  ...          1613           13
# 1           5199       1042      5.0  ...          1590            7
# 2           6070       1011      6.0  ...          2768           20
# 3           5772       1015      5.7  ...          1659           12
# 4           6264       1075      5.8  ...          2063           10
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2006 = df_2006.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2006.head()
# Out:
#    Year  Rk_Off                Team  Win  Loss  Games  PF_Off  Total Yds_Off  \
# 0  2006       1  San Diego Chargers   14     2     16     492           5840
# 1  2006       2       Chicago Bears   13     3     16     427           5199
# 2  2006       3  Indianapolis Colts   12     4     16     427           6070
# 3  2006       4      Dallas Cowboys    9     7     16     425           5772
# 4  2006       5  New Orleans Saints   10     6     16     413           6264
#
#    Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  Rush Y/A_Def  \
# 0       1016      5.7  ...          1613           13           4.2
# 1       1042      5.0  ...          1590            7           4.0
# 2       1011      6.0  ...          2768           20           5.3
# 3       1015      5.7  ...          1659           12           3.9
# 4       1075      5.8  ...          2063           10           4.9
#
#    Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  TO%_Def  EXP_Def
# ...

# %% [markdown]
# # 2007

# %%
df_2007 = offense_2007.merge(defense_2007, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2007.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2007       1  New England Patriots       16         0     16     589
# 1      2007       2        Dallas Cowboys       13         3     16     455
# 2      2007       3    Indianapolis Colts       13         3     16     450
# 3      2007       4     Green Bay Packers       13         3     16     435
# 4      2007       5    San Diego Chargers       11         5     16     412
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6580       1058      6.2  ...          1572            7
# 1           5851        975      6.0  ...          1513           12
# 2           5739       1020      5.6  ...          1711           10
# 3           5931        985      6.0  ...          1647            6
# 4           5044        980      5.1  ...          1712           11
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2007 = df_2007.drop('Year_Def', 1)
df_2007 = df_2007.drop('Win_Def', 1)
df_2007 = df_2007.drop('Loss_Def', 1) 
df_2007 = df_2007.drop('Tm_Def', 1)
df_2007 = df_2007.drop('G_Def', 1)
df_2007.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2007       1  New England Patriots       16         0     16     589
# 1      2007       2        Dallas Cowboys       13         3     16     455
# 2      2007       3    Indianapolis Colts       13         3     16     450
# 3      2007       4     Green Bay Packers       13         3     16     435
# 4      2007       5    San Diego Chargers       11         5     16     412
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6580       1058      6.2  ...          1572            7
# 1           5851        975      6.0  ...          1513           12
# 2           5739       1020      5.6  ...          1711           10
# 3           5931        985      6.0  ...          1647            6
# 4           5044        980      5.1  ...          1712           11
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2007 = df_2007.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2007.head()
# Out:
#    Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0  2007       1  New England Patriots   16     0     16     589
# 1  2007       2        Dallas Cowboys   13     3     16     455
# 2  2007       3    Indianapolis Colts   13     3     16     450
# 3  2007       4     Green Bay Packers   13     3     16     435
# 4  2007       5    San Diego Chargers   11     5     16     412
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6580       1058      6.2  ...          1572            7
# 1           5851        975      6.0  ...          1513           12
# 2           5739       1020      5.6  ...          1711           10
# 3           5931        985      6.0  ...          1647            6
# 4           5044        980      5.1  ...          1712           11
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# 0           4.4             91       96          764         15     24.0
# ...

# %% [markdown]
# # 2008

# %%
df_2008 = offense_2008.merge(defense_2008, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2008.head()
# Out:
#    Year_Off  Rk_Off              Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2008       1  New Orleans Saints        8         8     16     463
# 1      2008       2  San Diego Chargers        8         8     16     439
# 2      2008       3     New York Giants       12         4     16     427
# 3      2008       4   Arizona Cardinals        9         7     16     427
# 4      2008       5   Green Bay Packers        6        10     16     419
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6571       1047      6.3  ...          1885           14
# 1           5584        924      6.0  ...          1641           11
# 2           5695       1021      5.6  ...          1533           14
# 3           5852        998      5.9  ...          1764           13
# 4           5618       1012      5.6  ...          2105           20
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2008 = df_2008.drop('Year_Def', 1)
df_2008 = df_2008.drop('Win_Def', 1)
df_2008 = df_2008.drop('Loss_Def', 1) 
df_2008 = df_2008.drop('Tm_Def', 1)
df_2008 = df_2008.drop('G_Def', 1)
df_2008.head()
# Out:
#    Year_Off  Rk_Off              Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2008       1  New Orleans Saints        8         8     16     463
# 1      2008       2  San Diego Chargers        8         8     16     439
# 2      2008       3     New York Giants       12         4     16     427
# 3      2008       4   Arizona Cardinals        9         7     16     427
# 4      2008       5   Green Bay Packers        6        10     16     419
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6571       1047      6.3  ...          1885           14
# 1           5584        924      6.0  ...          1641           11
# 2           5695       1021      5.6  ...          1533           14
# 3           5852        998      5.9  ...          1764           13
# 4           5618       1012      5.6  ...          2105           20
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2008 = df_2008.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2008.head()
# Out:
#    Year  Rk_Off                Team  Win  Loss  Games  PF_Off  Total Yds_Off  \
# 0  2008       1  New Orleans Saints    8     8     16     463           6571
# 1  2008       2  San Diego Chargers    8     8     16     439           5584
# 2  2008       3     New York Giants   12     4     16     427           5695
# 3  2008       4   Arizona Cardinals    9     7     16     427           5852
# 4  2008       5   Green Bay Packers    6    10     16     419           5618
#
#    Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  Rush Y/A_Def  \
# 0       1047      6.3  ...          1885           14           4.2
# 1        924      6.0  ...          1641           11           4.0
# 2       1021      5.6  ...          1533           14           4.0
# 3        998      5.9  ...          1764           13           4.0
# 4       1012      5.6  ...          2105           20           4.6
#
#    Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  TO%_Def  EXP_Def
# ...

# %% [markdown]
# # 2009

# %%
df_2009 = offense_2009.merge(defense_2009, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2009.head()
# Out:
#    Year_Off  Rk_Off               Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2009       1   New Orleans Saints       13         3     16     510
# 1      2009       2    Minnesota Vikings       12         4     16     470
# 2      2009       3    Green Bay Packers       11         5     16     461
# 3      2009       4   San Diego Chargers       13         3     16     454
# 4      2009       5  Philadelphia Eagles       11         5     16     429
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6461       1032      6.3  ...          1955           19
# 1           6074       1054      5.8  ...          1394            5
# 2           6065       1042      5.8  ...          1333            5
# 3           5761        972      5.9  ...          1884           10
# 4           5726        975      5.9  ...          1675           11
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2009 = df_2009.drop('Year_Def', 1)
df_2009 = df_2009.drop('Win_Def', 1)
df_2009 = df_2009.drop('Loss_Def', 1) 
df_2009 = df_2009.drop('Tm_Def', 1)
df_2009 = df_2009.drop('G_Def', 1)
df_2009.head()
# Out:
#    Year_Off  Rk_Off               Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2009       1   New Orleans Saints       13         3     16     510
# 1      2009       2    Minnesota Vikings       12         4     16     470
# 2      2009       3    Green Bay Packers       11         5     16     461
# 3      2009       4   San Diego Chargers       13         3     16     454
# 4      2009       5  Philadelphia Eagles       11         5     16     429
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6461       1032      6.3  ...          1955           19
# 1           6074       1054      5.8  ...          1394            5
# 2           6065       1042      5.8  ...          1333            5
# 3           5761        972      5.9  ...          1884           10
# 4           5726        975      5.9  ...          1675           11
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2009 = df_2009.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2009.head()
# Out:
#    Year  Rk_Off                 Team  Win  Loss  Games  PF_Off  Total Yds_Off  \
# 0  2009       1   New Orleans Saints   13     3     16     510           6461
# 1  2009       2    Minnesota Vikings   12     4     16     470           6074
# 2  2009       3    Green Bay Packers   11     5     16     461           6065
# 3  2009       4   San Diego Chargers   13     3     16     454           5761
# 4  2009       5  Philadelphia Eagles   11     5     16     429           5726
#
#    Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  Rush Y/A_Def  \
# 0       1032      6.3  ...          1955           19           4.5
# 1       1054      5.8  ...          1394            5           3.9
# 2       1042      5.8  ...          1333            5           3.6
# 3        972      5.9  ...          1884           10           4.5
# 4        975      5.9  ...          1675           11           4.1
#
#    Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  TO%_Def  EXP_Def
# ...

# %% [markdown]
# # Combine all years

# %%
combined_df = df_2005[:32].append([df_2006[:32], df_2007[:32], df_2008[:32], df_2009[:32]])
combined_df
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2005       1      Seattle Seahawks   13     3     16     452
# 1   2005       2    Indianapolis Colts   14     2     16     439
# 2   2005       3       New York Giants   11     5     16     422
# 3   2005       4    Cincinnati Bengals   11     5     16     421
# 4   2005       5    San Diego Chargers    9     7     16     418
# ..   ...     ...                   ...  ...   ...    ...     ...
# 27  2009      28         Buffalo Bills    6    10     16     258
# 28  2009      29      Cleveland Browns    5    11     16     245
# 29  2009      30  Tampa Bay Buccaneers    3    13     16     244
# 30  2009      31       Oakland Raiders    5    11     16     197
# 31  2009      32        St. Louis Rams    1    15     16     175
#
#     Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0            5915       1020      5.8  ...          1510            5
# ...

# %%
combined_df.to_csv('../Team_Stats/2005-2009_cleaned_data.csv', index = False)
