# %%
import pandas as pd

# %%
df_2000_2004 = pd.read_csv("../Data/Team_Stats/2000-2004.csv")
df_2005_2009 = pd.read_csv("../Data/Team_Stats/2005-2009_cleaned_data.csv")
df_2010_2014 = pd.read_csv("../Data/Team_Stats/2010to2014Combined.csv")
df_2015_2019 = pd.read_csv("../Data/Team_Stats/2015-2019_cleaned_data.csv")

# %%
combined_df = df_2000_2004[:158].append([df_2005_2009[:160], df_2010_2014[:160], df_2015_2019[:160]])
combined_df
# Out:
#        Year  Rk_Off                Team  Wins  Losses     G  PF_Off  \
# 0    2000.0       1      St. Louis Rams  10.0     6.0  16.0     540
# 1    2000.0       2      Denver Broncos  11.0     5.0  16.0     485
# 2    2000.0       3     Oakland Raiders  12.0     4.0  16.0     479
# 3    2000.0       4  Indianapolis Colts  10.0     6.0  16.0     429
# 4    2000.0       5   Minnesota Vikings  11.0     5.0  16.0     397
# ..      ...     ...                 ...   ...     ...   ...     ...
# 155     NaN      28                 NaN   NaN     NaN   NaN     282
# 156     NaN      29                 NaN   NaN     NaN   NaN     280
# 157     NaN      30                 NaN   NaN     NaN   NaN     279
# 158     NaN      31                 NaN   NaN     NaN   NaN     276
# 159     NaN      32                 NaN   NaN     NaN   NaN     266
#
#      Total Yds_Off  Plays_Off  Y/P_Off  ...  Year_Off               Tm_Off  \
# ...

# %%
combined_df['Overall Production'] = ""
combined_df
# Out:
#        Year  Rk_Off                Team  Wins  Losses     G  PF_Off  \
# 0    2000.0       1      St. Louis Rams  10.0     6.0  16.0     540
# 1    2000.0       2      Denver Broncos  11.0     5.0  16.0     485
# 2    2000.0       3     Oakland Raiders  12.0     4.0  16.0     479
# 3    2000.0       4  Indianapolis Colts  10.0     6.0  16.0     429
# 4    2000.0       5   Minnesota Vikings  11.0     5.0  16.0     397
# ..      ...     ...                 ...   ...     ...   ...     ...
# 155     NaN      28                 NaN   NaN     NaN   NaN     282
# 156     NaN      29                 NaN   NaN     NaN   NaN     280
# 157     NaN      30                 NaN   NaN     NaN   NaN     279
# 158     NaN      31                 NaN   NaN     NaN   NaN     276
# 159     NaN      32                 NaN   NaN     NaN   NaN     266
#
#      Total Yds_Off  Plays_Off  Y/P_Off  ...               Tm_Off  Win_Off  \
# 0             7075       1014      7.0  ...                  NaN      NaN
# ...

# %%
for index, row in combined_df.iterrows():
    off_yards = combined_df['Total Yds_Off']
    def_yards = combined_df['Total Yds_Def']
    
    combined_df.loc[index, "Overall Production"] = off_yards - def_yards
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ed8e3effc6e1> in <module>
#       3     def_yards = combined_df['Total Yds_Def']
#       4
# ----> 5     combined_df.loc[index, "Overall Production"] = off_yards - def_yards
#       6
#
# ~\Anaconda3\envs\PythonData_RU_2020\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\envs\PythonData_RU_2020\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     888
#     889             if isinstance(value, ABCSeries):
# --> 890                 value = self._align_series(indexer, value)
#     891
# ...
