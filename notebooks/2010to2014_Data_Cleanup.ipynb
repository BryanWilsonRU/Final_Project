# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
OFF10 = "2010OffenseRenamed.csv"
OFF11 = "2011OffenseRenamed.csv"
OFF12 = "2012OffenseRenamed.csv"
OFF13 = "2013OffenseRenamed.csv"
OFF14 = "2014OffenseRenamed.csv"
DEF10 = "2010DefenseRenamed.csv"
DEF11 = "2011DefenseRenamed.csv"
DEF12 = "2012DefenseRenamed.csv"
DEF13 = "2013DefenseRenamed.csv"
DEF14 = "2014DefenseRenamed.csv"

# %%
# Import & read csv
OFF10df = pd.read_csv(OFF10)
OFF11df = pd.read_csv(OFF11)
OFF12df = pd.read_csv(OFF12)
OFF13df = pd.read_csv(OFF13)
OFF14df = pd.read_csv(OFF14)
DEF10df = pd.read_csv(DEF10)
DEF11df = pd.read_csv(DEF11)
DEF12df = pd.read_csv(DEF12)
DEF13df = pd.read_csv(DEF13)
DEF14df = pd.read_csv(DEF14)

# %%
df_2010 = OFF10df.merge(DEF10df, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2010.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2010       1  New England Patriots       14         2     16     518
# 1      2010       2    San Diego Chargers        9         7     16     441
# 2      2010       3   Philadelphia Eagles       10         6     16     439
# 3      2010       4    Indianapolis Colts       10         6     16     435
# 4      2010       5       Atlanta Falcons       13         3     16     414
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5820        986      5.9  ...          1728           10
# 1           6329       1039      6.1  ...          1500           14
# 2           6230       1038      6.0  ...          1766           12
# 3           6092       1088      5.6  ...          2032           14
# 4           5458       1097      5.0  ...          1694            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2010 = df_2010.drop('Year_Def', 1)
df_2010 = df_2010.drop('Win_Def', 1)
df_2010 = df_2010.drop('Loss_Def', 1) 
df_2010 = df_2010.drop('Tm_Def', 1)
df_2010 = df_2010.drop('G_Def', 1)

# %%
df_2010 = df_2010.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2010
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2010       1  New England Patriots   14     2     16     518
# 1   2010       2    San Diego Chargers    9     7     16     441
# 2   2010       3   Philadelphia Eagles   10     6     16     439
# 3   2010       4    Indianapolis Colts   10     6     16     435
# 4   2010       5       Atlanta Falcons   13     3     16     414
# 5   2010       6       Oakland Raiders    8     8     16     410
# 6   2010       7        Dallas Cowboys    6    10     16     394
# 7   2010       8       New York Giants   10     6     16     394
# 8   2010       9        Houston Texans    6    10     16     390
# 9   2010      10     Green Bay Packers   10     6     16     388
# 10  2010      11    New Orleans Saints   11     5     16     384
# 11  2010      12   Pittsburgh Steelers   12     4     16     375
# 12  2010      13         New York Jets   11     5     16     367
# ...

# %%
df_2011 = OFF11df.merge(DEF11df, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2011.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2011       1     Green Bay Packers       15         1     16     560
# 1      2011       2    New Orleans Saints       13         3     16     547
# 2      2011       3  New England Patriots       13         3     16     513
# 3      2011       4         Detroit Lions       10         6     16     474
# 4      2011       5     Carolina Panthers        6        10     16     406
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6482        988      6.6  ...          1789           10
# 1           7474       1117      6.7  ...          1738           11
# 2           6848       1082      6.3  ...          1874           13
# 3           6337       1058      6.0  ...          2050           10
# 4           6237        999      6.2  ...          2093           18
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2011 = df_2011.drop('Year_Def', 1)
df_2011 = df_2011.drop('Win_Def', 1)
df_2011 = df_2011.drop('Loss_Def', 1) 
df_2011 = df_2011.drop('Tm_Def', 1)
df_2011 = df_2011.drop('G_Def', 1)

# %%
df_2011 = df_2011.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2011
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2011       1     Green Bay Packers   15     1     16     560
# 1   2011       2    New Orleans Saints   13     3     16     547
# 2   2011       3  New England Patriots   13     3     16     513
# 3   2011       4         Detroit Lions   10     6     16     474
# 4   2011       5     Carolina Panthers    6    10     16     406
# 5   2011       6    San Diego Chargers    8     8     16     406
# 6   2011       7       Atlanta Falcons   10     6     16     402
# 7   2011       8   Philadelphia Eagles    8     8     16     396
# 8   2011       9       New York Giants    9     7     16     394
# 9   2011      10        Houston Texans   10     6     16     381
# 10  2011      11   San Francisco 49ers   13     3     16     380
# 11  2011      12      Baltimore Ravens   12     4     16     378
# 12  2011      13         New York Jets    8     8     16     377
# ...

# %%
df_2012 = OFF12df.merge(DEF12df, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2012.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2012       1  New England Patriots       12         4     16     557
# 1      2012       2        Denver Broncos       13         3     16     481
# 2      2012       3    New Orleans Saints        7         9     16     461
# 3      2012       4   Washington Redskins       10         6     16     436
# 4      2012       5     Green Bay Packers       11         5     16     433
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6846       1191      5.7  ...          1630           10
# 1           6366       1090      5.8  ...          1458            5
# 2           6574       1067      6.2  ...          2361           18
# 3           6131        994      6.2  ...          1532           11
# 4           5751       1042      5.5  ...          1896           12
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2012 = df_2012.drop('Year_Def', 1)
df_2012 = df_2012.drop('Win_Def', 1)
df_2012 = df_2012.drop('Loss_Def', 1) 
df_2012 = df_2012.drop('Tm_Def', 1)
df_2012 = df_2012.drop('G_Def', 1)

# %%
df_2012 = df_2012.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2012
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2012       1  New England Patriots   12     4     16     557
# 1   2012       2        Denver Broncos   13     3     16     481
# 2   2012       3    New Orleans Saints    7     9     16     461
# 3   2012       4   Washington Redskins   10     6     16     436
# 4   2012       5     Green Bay Packers   11     5     16     433
# 5   2012       6       New York Giants    9     7     16     429
# 6   2012       7       Atlanta Falcons   13     3     16     419
# 7   2012       8        Houston Texans   12     4     16     416
# 8   2012       9      Seattle Seahawks   11     5     16     412
# 9   2012      10      Baltimore Ravens   10     6     16     398
# 10  2012      11   San Francisco 49ers   11     4     16     397
# 11  2012      12    Cincinnati Bengals   10     6     16     391
# 12  2012      13  Tampa Bay Buccaneers    7     9     16     389
# ...

# %%
df_2013 = OFF13df.merge(DEF13df, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2013.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2013       1        Denver Broncos       13         3     16     606
# 1      2013       2         Chicago Bears        8         8     16     445
# 2      2013       3  New England Patriots       12         4     16     444
# 3      2013       4   Philadelphia Eagles       10         6     16     442
# 4      2013       5        Dallas Cowboys        8         8     16     439
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           7317       1156      6.3  ...          1626           15
# 1           6109       1013      6.0  ...          2583           22
# 2           6152       1138      5.4  ...          2145           11
# 3           6676       1054      6.3  ...          1668           12
# 4           5458        957      5.7  ...          2056           17
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2013 = df_2013.drop('Year_Def', 1)
df_2013 = df_2013.drop('Win_Def', 1)
df_2013 = df_2013.drop('Loss_Def', 1) 
df_2013 = df_2013.drop('Tm_Def', 1)
df_2013 = df_2013.drop('G_Def', 1)

# %%
df_2013 = df_2013.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2013
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2013       1        Denver Broncos   13     3     16     606
# 1   2013       2         Chicago Bears    8     8     16     445
# 2   2013       3  New England Patriots   12     4     16     444
# 3   2013       4   Philadelphia Eagles   10     6     16     442
# 4   2013       5        Dallas Cowboys    8     8     16     439
# 5   2013       6    Cincinnati Bengals   11     5     16     430
# 6   2013       7    Kansas City Chiefs   11     5     16     430
# 7   2013       8     Green Bay Packers    8     7     16     417
# 8   2013       9      Seattle Seahawks   13     3     16     417
# 9   2013      10    New Orleans Saints   11     5     16     414
# 10  2013      11   San Francisco 49ers   12     4     16     406
# 11  2013      12    San Diego Chargers    9     7     16     396
# 12  2013      13         Detroit Lions    7     9     16     395
# ...

# %%
df_2014 = OFF14df.merge(DEF14df, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2014.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2014       1     Green Bay Packers       12         4     16     486
# 1      2014       2        Denver Broncos       12         4     16     482
# 2      2014       3   Philadelphia Eagles       10         6     16     474
# 3      2014       4  New England Patriots       12         4     16     468
# 4      2014       5        Dallas Cowboys       12         4     16     467
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6178       1001      6.2  ...          1919           11
# 1           6446       1067      6.0  ...          1276            9
# 2           6348       1127      5.6  ...          1771           14
# 3           5848       1073      5.5  ...          1669            6
# 4           6138       1014      6.1  ...          1650           18
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2014 = df_2014.drop('Year_Def', 1)
df_2014 = df_2014.drop('Win_Def', 1)
df_2014 = df_2014.drop('Loss_Def', 1) 
df_2014 = df_2014.drop('Tm_Def', 1)
df_2014 = df_2014.drop('G_Def', 1)

# %%
df_2014 = df_2014.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2014
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2014       1     Green Bay Packers   12     4     16     486
# 1   2014       2        Denver Broncos   12     4     16     482
# 2   2014       3   Philadelphia Eagles   10     6     16     474
# 3   2014       4  New England Patriots   12     4     16     468
# 4   2014       5        Dallas Cowboys   12     4     16     467
# 5   2014       6    Indianapolis Colts   11     5     16     458
# 6   2014       7   Pittsburgh Steelers   11     5     16     436
# 7   2014       8      Baltimore Ravens   10     6     16     409
# 8   2014       9    New Orleans Saints    7     9     16     401
# 9   2014      10      Seattle Seahawks   12     4     16     394
# 10  2014      11        Miami Dolphins    8     8     16     388
# 11  2014      12       Atlanta Falcons    6    10     16     381
# 12  2014      13       New York Giants    6    10     16     380
# ...

# %%
combined_df = df_2010[:32].append([df_2011[:32], df_2012[:32], df_2013[:32], df_2014[:32]])
combined_df
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2010       1  New England Patriots   14     2     16     518
# 1   2010       2    San Diego Chargers    9     7     16     441
# 2   2010       3   Philadelphia Eagles   10     6     16     439
# 3   2010       4    Indianapolis Colts   10     6     16     435
# 4   2010       5       Atlanta Falcons   13     3     16     414
# ..   ...     ...                   ...  ...   ...    ...     ...
# 27  2014      28         New York Jets    4    12     16     283
# 28  2014      29  Tampa Bay Buccaneers    2    14     16     277
# 29  2014      30      Tennessee Titans    2    14     16     254
# 30  2014      31       Oakland Raiders    3    13     16     253
# 31  2014      32  Jacksonville Jaguars    3    13     16     249
#
#     Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0            5820        986      5.9  ...          1728           10
# ...

# %%
combined_df.to_csv(r'2010to2014_DataCleanup.csv', index = False)
