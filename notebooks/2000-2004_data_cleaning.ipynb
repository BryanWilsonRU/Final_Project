# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Files to Load
d2000_path = "../Data/Team_Stats/2000_team_defense.csv"
o2000_path = "../Data/Team_Stats/2000_team_offense.csv"
d2001_path = "../Data/Team_Stats/2001_team_defense.csv"
o2001_path = "../Data/Team_Stats/2001_team_offense.csv"
d2002_path = "../Data/Team_Stats/2002_team_defense.csv"
o2002_path = "../Data/Team_Stats/2002_team_offense.csv"
d2003_path = "../Data/Team_Stats/2003_team_defense.csv"
o2003_path = "../Data/Team_Stats/2003_team_offense.csv"
d2004_path = "../Data/Team_Stats/2004_team_defense.csv"
o2004_path = "../Data/Team_Stats/2004_team_offense.csv"

# %%
# Read files and store into Pandas data frames
d2000_df = pd.read_csv(d2000_path)
o2000_df = pd.read_csv(o2000_path)
d2001_df = pd.read_csv(d2001_path)
o2001_df = pd.read_csv(o2001_path)
d2002_df = pd.read_csv(d2002_path)
o2002_df = pd.read_csv(o2002_path)
d2003_df = pd.read_csv(d2003_path)
o2003_df = pd.read_csv(o2003_path)
d2004_df = pd.read_csv(d2004_path)
o2004_df = pd.read_csv(o2004_path)

# %%
# Fill NaN values with 0
d2000_df = d2000_df.fillna(0)
o2000_df = o2000_df.fillna(0)
d2001_df = d2001_df.fillna(0)
o2001_df = o2001_df.fillna(0)
d2002_df = d2002_df.fillna(0)
o2002_df = o2002_df.fillna(0)
d2003_df = d2003_df.fillna(0)
o2003_df = o2003_df.fillna(0)
d2004_df = d2004_df.fillna(0)
o2004_df = o2004_df.fillna(0)

# %%
# Display sample DF for review
d2000_df.head()
# Out:
#    Year_Def  Rk_Def               Tm_Def  Win_Def  Loss_Def  G_Def  PF_Def  \
# 0      2000       1     Baltimore Ravens       12         4     16     165
# 1      2000       2     Tennessee Titans       13         3     16     191
# 2      2000       3       Miami Dolphins       11         5     16     226
# 3      2000       4  Philadelphia Eagles       11         5     16     245
# 4      2000       5      New York Giants       12         4     16     246
#
#    Total Yds_Def  Ply_Def  Y/P_Def  ...  Rush Yds_Def  Rush TD_Def  \
# 0           3967      924      4.3  ...           970            5
# 1           3813      908      4.2  ...          1390            7
# 2           4636      995      4.7  ...          1736            9
# 3           4820     1055      4.6  ...          1830           10
# 4           4546      988      4.6  ...          1156            7
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
# Rename columns so they combine when merging
d2000r_df = d2000_df.rename(columns={"Year_Def":"Year","Tm_Def":"Team","Win_Def":"Wins","Loss_Def":"Losses","G_Def":"G"})
o2000r_df = o2000_df.rename(columns={"Year_Off":"Year","Tm_Off":"Team","Win_Off":"Wins","Loss_Off":"Losses","G_Off":"G"})
d2001r_df = d2001_df.rename(columns={"Year_Def":"Year","Tm_Def":"Team","Win_Def":"Wins","Loss_Def":"Losses","G_Def":"G"})
o2001r_df = o2001_df.rename(columns={"Year_Off":"Year","Tm_Off":"Team","Win_Off":"Wins","Loss_Off":"Losses","G_Off":"G"})
d2002r_df = d2002_df.rename(columns={"Year_Def":"Year","Tm_Def":"Team","Win_Def":"Wins","Loss_Def":"Losses","G_Def":"G"})
o2002r_df = o2002_df.rename(columns={"Year_Off":"Year","Tm_Off":"Team","Win_Off":"Wins","Loss_Off":"Losses","G_Off":"G"})
d2003r_df = d2003_df.rename(columns={"Year_Def":"Year","Tm_Def":"Team","Win_Def":"Wins","Loss_Def":"Losses","G_Def":"G"})
o2003r_df = o2003_df.rename(columns={"Year_Off":"Year","Tm_Off":"Team","Win_Off":"Wins","Loss_Off":"Losses","G_Off":"G"})
d2004r_df = d2004_df.rename(columns={"Year_Def":"Year","Tm_Def":"Team","Win_Def":"Wins","Loss_Def":"Losses","G_Def":"G"})
o2004r_df = o2004_df.rename(columns={"Year_Off":"Year","Tm_Off":"Team","Win_Off":"Wins","Loss_Off":"Losses","G_Off":"G"})

# %%
o2000r_df.columns
# Out:
# Index(['Year', 'Rk_Off', 'Team', 'Wins', 'Losses', 'G', 'PF_Off',
#        'Total Yds_Off', 'Plays_Off', 'Y/P_Off', 'TO_Off', 'FL_Off', '1stD_Off',
#        'Cmp_Off', 'Pass Att_Off', 'Pass Yds_Off', 'Pass TD_Off', 'Int_Off',
#        'Pass NY/A_Off', 'Pass 1stD_Off', 'Rush Att_Off', 'Rush Yds_Off',
#        'Rush TD_Off', 'Rush Y/A_Off', 'Rush 1stD_Off', 'Pen_Off',
#        'Pen Yds_Off', '1stPy_Off', 'Sc%_Off', 'TO%_Off', 'EXP_Off'],
#       dtype='object')

# %%
# Reorder Columns for merge
d2000r_df = d2000r_df[["Year","Team","Wins","Losses","G","Rk_Def","PF_Def","Total Yds_Def","Ply_Def","Y/P_Def","TO_Def","FL_Def","Total 1stD_Def","Cmp_Def","Pass Att_Def","Pass Yds_Def","Pass TD_Def","Int_Def","Pass NY/A_Def","Pass 1stD_Def","Rush Att_Def","Rush Yds_Def","Rush TD_Def","Rush Y/A_Def","Rush 1stD_Def","Pen_Def","Pen Yds_Def","1stPy_Def","Sc%_Def","TO%_Def","EXP_Def"]]
o2000r_df = o2000r_df[["Year","Team","Wins","Losses","G","Rk_Off","PF_Off","Total Yds_Off","Plays_Off","Y/P_Off","TO_Off","FL_Off","1stD_Off","Cmp_Off","Pass Att_Off","Pass Yds_Off","Pass TD_Off","Int_Off","Pass NY/A_Off","Pass 1stD_Off","Rush Att_Off","Rush Yds_Off","Rush TD_Off","Rush Y/A_Off","Rush 1stD_Off","Pen_Off","Pen Yds_Off","1stPy_Off","Sc%_Off","TO%_Off","EXP_Off"]]
d2001r_df = d2001r_df[["Year","Team","Wins","Losses","G","Rk_Def","PF_Def","Total Yds_Def","Ply_Def","Y/P_Def","TO_Def","FL_Def","Total 1stD_Def","Cmp_Def","Pass Att_Def","Pass Yds_Def","Pass TD_Def","Int_Def","Pass NY/A_Def","Pass 1stD_Def","Rush Att_Def","Rush Yds_Def","Rush TD_Def","Rush Y/A_Def","Rush 1stD_Def","Pen_Def","Pen Yds_Def","1stPy_Def","Sc%_Def","TO%_Def","EXP_Def"]]
d2004r_df = d2004r_df[["Year","Team","Wins","Losses","G","Rk_Def","PF_Def","Total Yds_Def","Ply_Def","Y/P_Def","TO_Def","FL_Def","Total 1stD_Def","Cmp_Def","Pass Att_Def","Pass Yds_Def","Pass TD_Def","Int_Def","Pass NY/A_Def","Pass 1stD_Def","Rush Att_Def","Rush Yds_Def","Rush TD_Def","Rush Y/A_Def","Rush 1stD_Def","Pen_Def","Pen Yds_Def","1stPy_Def","Sc%_Def","TO%_Def","EXP_Def"]]
o2004r_df = o2004r_df[["Year","Team","Wins","Losses","G","Rk_Off","PF_Off","Total Yds_Off","Plays_Off","Y/P_Off","TO_Off","FL_Off","1stD_Off","Cmp_Off","Pass Att_Off","Pass Yds_Off","Pass TD_Off","Int_Off","Pass NY/A_Off","Pass 1stD_Off","Rush Att_Off","Rush Yds_Off","Rush TD_Off","Rush Y/A_Off","Rush 1stD_Off","Pen_Off","Pen Yds_Off","1stPy_Off","Sc%_Off","TO%_Off","EXP_Off"]]

# %%
# Combine Year DFs into single DF
y2000_df = o2000r_df.merge(d2000r_df, how='inner')
y2001_df = o2001r_df.merge(d2001r_df, how='inner')
y2002_df = o2002r_df.merge(d2002r_df, how='inner')
y2003_df = o2003r_df.merge(d2003r_df, how='inner')
y2004_df = o2004r_df.merge(d2004r_df, how='inner')

# %%
# Display one combined DF for error checking
y2004_df
# Out:
#     Year                  Team  Wins  Losses   G  Rk_Off  PF_Off  \
# 0   2004    Indianapolis Colts    12       4  16       1     522
# 1   2004    Kansas City Chiefs     7       9  16       2     483
# 2   2004    San Diego Chargers    12       4  16       3     446
# 3   2004  New England Patriots    14       2  16       4     437
# 4   2004     Green Bay Packers    10       6  16       5     424
# 5   2004     Minnesota Vikings     8       8  16       6     405
# 6   2004         Buffalo Bills     9       7  16       7     395
# 7   2004   Philadelphia Eagles    13       3  16       8     386
# 8   2004        Denver Broncos    10       6  16       9     381
# 9   2004    Cincinnati Bengals     8       8  16      10     374
# 10  2004   Pittsburgh Steelers    15       1  16      11     372
# 11  2004      Seattle Seahawks     9       7  16      12     371
# 12  2004     Carolina Panthers     7       9  16      13     355
# ...

# %%
# Combine annual DFs into one combined DF
combined_df = y2000_df[:31].append([y2001_df[:31], y2002_df[:32], y2003_df[:32], y2004_df[:32]])
combined_df
# Out:
#     Year                  Team  Wins  Losses   G  Rk_Off  PF_Off  \
# 0   2000        St. Louis Rams    10       6  16       1     540
# 1   2000        Denver Broncos    11       5  16       2     485
# 2   2000       Oakland Raiders    12       4  16       3     479
# 3   2000    Indianapolis Colts    10       6  16       4     429
# 4   2000     Minnesota Vikings    11       5  16       5     397
# ..   ...                   ...   ...     ...  ..     ...     ...
# 27  2004        Miami Dolphins     4      12  16      28     275
# 28  2004  Jacksonville Jaguars     9       7  16      29     261
# 29  2004   San Francisco 49ers     2      14  16      30     259
# 30  2004   Washington Redskins     6      10  16      31     240
# 31  2004         Chicago Bears     5      11  16      32     231
#
#     Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0            7075       1014      7.0  ...          1697           18
# ...

# %%
#Write combined DataFrame to .csv
combined_df.to_csv("../Data/Team_Stats/2000-2004_cleaned_data.csv",index=False)
