# %%
import pandas as pd

# %%
#All defense csvs
df15=pd.read_csv('../Data/Team_Stats/2015_team_defense.csv')
df16=pd.read_csv('../Data/Team_Stats/2016_team_defense.csv')
df17=pd.read_csv('../Data/Team_Stats/2017_team_defense.csv')
df18=pd.read_csv('../Data/Team_Stats/2018_team_defense.csv')
df19=pd.read_csv('../Data/Team_Stats/2019_team_defense.csv')
# df_merge= df15[:32].append([df16[:32], df17[:32], df18[:32], df19[:32]])
# df_merge.to_csv('2015-2019_defense.csv')

# %%
#All offense csvs
of15=pd.read_csv('../Data/Team_Stats/2015_team_offense.csv')
of16=pd.read_csv('../Data/Team_Stats/2016_team_offense.csv')
of17=pd.read_csv('../Data/Team_Stats/2017_team_offense.csv')
of18=pd.read_csv('../Data/Team_Stats/2018_team_offense.csv')
of19=pd.read_csv('../Data/Team_Stats/2019_team_offense.csv')
# of_merge= of15[:32].append([of16[:32], of17[:32], of18[:32], of19[:32]])
# of_merge.to_csv('2015-2019_offense.csv')

# %%
#2015
df_2015 = of15.merge(df15, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2015.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2015       1     Carolina Panthers       15         1     16     500
# 1      2015       2     Arizona Cardinals       13         3     16     489
# 2      2015       3  New England Patriots       12         4     16     465
# 3      2015       4      Seattle Seahawks       10         6     16     423
# 4      2015       5   Pittsburgh Steelers       10         6     16     423
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5871       1060      5.5  ...          1415           11
# 1           6533       1041      6.3  ...          1460            9
# 2           5991       1050      5.7  ...          1578            8
# 3           6058       1035      5.9  ...          1304           10
# 4           6327       1011      6.3  ...          1459            6
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2015 = df_2015.drop('Year_Def', 1)
df_2015 = df_2015.drop('Win_Def', 1)
df_2015 = df_2015.drop('Loss_Def', 1) 
df_2015 = df_2015.drop('Tm_Def', 1)
df_2015 = df_2015.drop('G_Def', 1)
df_2015.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2015       1     Carolina Panthers       15         1     16     500
# 1      2015       2     Arizona Cardinals       13         3     16     489
# 2      2015       3  New England Patriots       12         4     16     465
# 3      2015       4      Seattle Seahawks       10         6     16     423
# 4      2015       5   Pittsburgh Steelers       10         6     16     423
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5871       1060      5.5  ...          1415           11
# 1           6533       1041      6.3  ...          1460            9
# 2           5991       1050      5.7  ...          1578            8
# 3           6058       1035      5.9  ...          1304           10
# 4           6327       1011      6.3  ...          1459            6
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2015 = df_2015.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2015.head()
# Out:
#    Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0  2015       1     Carolina Panthers   15     1     16     500
# 1  2015       2     Arizona Cardinals   13     3     16     489
# 2  2015       3  New England Patriots   12     4     16     465
# 3  2015       4      Seattle Seahawks   10     6     16     423
# 4  2015       5   Pittsburgh Steelers   10     6     16     423
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5871       1060      5.5  ...          1415           11
# 1           6533       1041      6.3  ...          1460            9
# 2           5991       1050      5.7  ...          1578            8
# 3           6058       1035      5.9  ...          1304           10
# 4           6327       1011      6.3  ...          1459            6
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# 0           3.9             74       99          822         26     26.5
# ...

# %%
#2016
df_2016 = of16.merge(df16, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2016.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2016       1       Atlanta Falcons       11         5     16     540
# 1      2016       2    New Orleans Saints        7         9     16     469
# 2      2016       3  New England Patriots       14         2     16     441
# 3      2016       4     Green Bay Packers       10         6     16     432
# 4      2016       5        Dallas Cowboys       13         3     16     421
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6653        995      6.7  ...          1672           15
# 1           6816       1105      6.2  ...          1626           19
# 2           6180       1056      5.9  ...          1417            6
# 3           5900       1029      5.7  ...          1515           11
# 4           6027       1010      6.0  ...          1336            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2016 = df_2016.drop('Year_Def', 1)
df_2016 = df_2016.drop('Win_Def', 1)
df_2016 = df_2016.drop('Loss_Def', 1) 
df_2016 = df_2016.drop('Tm_Def', 1)
df_2016 = df_2016.drop('G_Def', 1)
df_2016.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2016       1       Atlanta Falcons       11         5     16     540
# 1      2016       2    New Orleans Saints        7         9     16     469
# 2      2016       3  New England Patriots       14         2     16     441
# 3      2016       4     Green Bay Packers       10         6     16     432
# 4      2016       5        Dallas Cowboys       13         3     16     421
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6653        995      6.7  ...          1672           15
# 1           6816       1105      6.2  ...          1626           19
# 2           6180       1056      5.9  ...          1417            6
# 3           5900       1029      5.7  ...          1515           11
# 4           6027       1010      6.0  ...          1336            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2016 = df_2016.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2016.head()
# Out:
#    Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0  2016       1       Atlanta Falcons   11     5     16     540
# 1  2016       2    New Orleans Saints    7     9     16     469
# 2  2016       3  New England Patriots   14     2     16     441
# 3  2016       4     Green Bay Packers   10     6     16     432
# 4  2016       5        Dallas Cowboys   13     3     16     421
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6653        995      6.7  ...          1672           15
# 1           6816       1105      6.2  ...          1626           19
# 2           6180       1056      5.9  ...          1417            6
# 3           5900       1029      5.7  ...          1515           11
# 4           6027       1010      6.0  ...          1336            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# 0           4.5             95      113          974         31     39.2
# ...

# %%
#2017
df_2017 = of17.merge(df17, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2017.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2017       1      Los Angeles Rams       11         5     16     478
# 1      2017       2  New England Patriots       13         3     16     458
# 2      2017       3   Philadelphia Eagles       13         3     16     457
# 3      2017       4    New Orleans Saints       11         5     16     448
# 4      2017       5  Jacksonville Jaguars       10         6     16     417
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5784       1000      5.8  ...          1957           15
# 1           6307       1070      5.9  ...          1836            6
# 2           5852       1073      5.5  ...          1267            7
# 3           6259       1000      6.3  ...          1787           11
# 4           5855       1078      5.4  ...          1860            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2017 = df_2017.drop('Year_Def', 1)
df_2017 = df_2017.drop('Win_Def', 1)
df_2017 = df_2017.drop('Loss_Def', 1) 
df_2017 = df_2017.drop('Tm_Def', 1)
df_2017 = df_2017.drop('G_Def', 1)
df_2017.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2017       1      Los Angeles Rams       11         5     16     478
# 1      2017       2  New England Patriots       13         3     16     458
# 2      2017       3   Philadelphia Eagles       13         3     16     457
# 3      2017       4    New Orleans Saints       11         5     16     448
# 4      2017       5  Jacksonville Jaguars       10         6     16     417
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5784       1000      5.8  ...          1957           15
# 1           6307       1070      5.9  ...          1836            6
# 2           5852       1073      5.5  ...          1267            7
# 3           6259       1000      6.3  ...          1787           11
# 4           5855       1078      5.4  ...          1860            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2017 = df_2017.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2017.head()
# Out:
#    Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0  2017       1      Los Angeles Rams   11     5     16     478
# 1  2017       2  New England Patriots   13     3     16     458
# 2  2017       3   Philadelphia Eagles   13     3     16     457
# 3  2017       4    New Orleans Saints   11     5     16     448
# 4  2017       5  Jacksonville Jaguars   10     6     16     417
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           5784       1000      5.8  ...          1957           15
# 1           6307       1070      5.9  ...          1836            6
# 2           5852       1073      5.5  ...          1267            7
# 3           6259       1000      6.3  ...          1787           11
# 4           5855       1078      5.4  ...          1860            9
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# 0           4.7             86      102          808         33     30.6
# ...

# %%
#2018
df_2018 = of18.merge(df18, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2018.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2018       1    Kansas City Chiefs       12         4     16     565
# 1      2018       2      Los Angeles Rams       13         3     16     527
# 2      2018       3    New Orleans Saints       13         3     16     504
# 3      2018       4  New England Patriots       11         5     16     436
# 4      2018       5    Indianapolis Colts       10         6     16     433
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6810        996      6.8  ...          2114           19
# 1           6738       1060      6.4  ...          1957           12
# 2           6067       1010      6.0  ...          1283           12
# 3           6295       1073      5.9  ...          1803            7
# 4           6179       1070      5.8  ...          1630           12
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2018 = df_2018.drop('Year_Def', 1)
df_2018 = df_2018.drop('Win_Def', 1)
df_2018 = df_2018.drop('Loss_Def', 1) 
df_2018 = df_2018.drop('Tm_Def', 1)
df_2018 = df_2018.drop('G_Def', 1)
df_2018.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2018       1    Kansas City Chiefs       12         4     16     565
# 1      2018       2      Los Angeles Rams       13         3     16     527
# 2      2018       3    New Orleans Saints       13         3     16     504
# 3      2018       4  New England Patriots       11         5     16     436
# 4      2018       5    Indianapolis Colts       10         6     16     433
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6810        996      6.8  ...          2114           19
# 1           6738       1060      6.4  ...          1957           12
# 2           6067       1010      6.0  ...          1283           12
# 3           6295       1073      5.9  ...          1803            7
# 4           6179       1070      5.8  ...          1630           12
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2018 = df_2018.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2018.head()
# Out:
#    Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0  2018       1    Kansas City Chiefs   12     4     16     565
# 1  2018       2      Los Angeles Rams   13     3     16     527
# 2  2018       3    New Orleans Saints   13     3     16     504
# 3  2018       4  New England Patriots   11     5     16     436
# 4  2018       5    Indianapolis Colts   10     6     16     433
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6810        996      6.8  ...          2114           19
# 1           6738       1060      6.4  ...          1957           12
# 2           6067       1010      6.0  ...          1283           12
# 3           6295       1073      5.9  ...          1803            7
# 4           6179       1070      5.8  ...          1630           12
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# 0           5.0            129      107          881         43     40.8
# ...

# %%
#2019
df_2019 = of19.merge(df19, how='inner', left_on='Tm_Off', right_on='Tm_Def')
df_2019.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2019       1      Baltimore Ravens       14         2     16     531
# 1      2019       2   San Francisco 49ers       13         3     16     479
# 2      2019       3  Tampa Bay Buccaneers        7         9     16     458
# 3      2019       4    New Orleans Saints       13         3     16     458
# 4      2019       5    Kansas City Chiefs       12         4     16     451
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6521       1064      6.1  ...          1494           12
# 1           6097       1012      6.0  ...          1802           11
# 2           6366       1086      5.9  ...          1181           11
# 3           5982       1011      5.9  ...          1461           12
# 4           6067        976      6.2  ...          2051           14
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2019 = df_2019.drop('Year_Def', 1)
df_2019 = df_2019.drop('Win_Def', 1)
df_2019 = df_2019.drop('Loss_Def', 1) 
df_2019 = df_2019.drop('Tm_Def', 1)
df_2019 = df_2019.drop('G_Def', 1)
df_2019.head()
# Out:
#    Year_Off  Rk_Off                Tm_Off  Win_Off  Loss_Off  G_Off  PF_Off  \
# 0      2019       1      Baltimore Ravens       14         2     16     531
# 1      2019       2   San Francisco 49ers       13         3     16     479
# 2      2019       3  Tampa Bay Buccaneers        7         9     16     458
# 3      2019       4    New Orleans Saints       13         3     16     458
# 4      2019       5    Kansas City Chiefs       12         4     16     451
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6521       1064      6.1  ...          1494           12
# 1           6097       1012      6.0  ...          1802           11
# 2           6366       1086      5.9  ...          1181           11
# 3           5982       1011      5.9  ...          1461           12
# 4           6067        976      6.2  ...          2051           14
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# ...

# %%
df_2019 = df_2019.rename(columns={'Year_Off': 'Year', 'Win_Off': 'Win', 'Loss_Off': 'Loss', 'Tm_Off': 'Team', 'G_Off': 'Games'})
df_2019.head()
# Out:
#    Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0  2019       1      Baltimore Ravens   14     2     16     531
# 1  2019       2   San Francisco 49ers   13     3     16     479
# 2  2019       3  Tampa Bay Buccaneers    7     9     16     458
# 3  2019       4    New Orleans Saints   13     3     16     458
# 4  2019       5    Kansas City Chiefs   12     4     16     451
#
#    Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0           6521       1064      6.1  ...          1494           12
# 1           6097       1012      6.0  ...          1802           11
# 2           6366       1086      5.9  ...          1181           11
# 3           5982       1011      5.9  ...          1461           12
# 4           6067        976      6.2  ...          2051           14
#
#    Rush Y/A_Def  Rush 1stD_Def  Pen_Def  Pen Yds_Def  1stPy_Def  Sc%_Def  \
# 0           4.4             74       97          795         39     32.9
# ...

# %%
#Combined All years
combined_df = df_2015[:32].append([df_2016[:32], df_2017[:32], df_2018[:32], df_2019[:32]])
combined_df
# Out:
#     Year  Rk_Off                  Team  Win  Loss  Games  PF_Off  \
# 0   2015       1     Carolina Panthers   15     1     16     500
# 1   2015       2     Arizona Cardinals   13     3     16     489
# 2   2015       3  New England Patriots   12     4     16     465
# 3   2015       4      Seattle Seahawks   10     6     16     423
# 4   2015       5   Pittsburgh Steelers   10     6     16     423
# ..   ...     ...                   ...  ...   ...    ...     ...
# 27  2019      28        Denver Broncos    7     9     16     282
# 28  2019      29         Chicago Bears    8     8     16     280
# 29  2019      30    Cincinnati Bengals    2    14     16     279
# 30  2019      31         New York Jets    7     9     16     276
# 31  2019      32   Washington Redskins    3    13     16     266
#
#     Total Yds_Off  Plays_Off  Y/P_Off  ...  Rush Yds_Def  Rush TD_Def  \
# 0            5871       1060      5.5  ...          1415           11
# ...

# %%
combined_df.to_csv('2015-2019_cleaned_data.csv', index = False)
