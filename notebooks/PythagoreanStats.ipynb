# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Files to Load
stats_path = "../Data/Team_Stats/2000-2019_cleaned_data3.csv"

# %%
# Read files and store into Pandas data frames
stats_df = pd.read_csv(stats_path)

# %%
# Fill NaN values with 0
stats_df = stats_df.fillna(0)

# %%
# Display sample DF for review
stats_df.head()
# Out:
#    Year  Rk_Off                Team  Win  Loss  Games  PF_Off  Total Yds_Off  \
# 0  2000       1      St. Louis Rams   10     6     16     540           7075
# 1  2000       2      Denver Broncos   11     5     16     485           6554
# 2  2000       3     Oakland Raiders   12     4     16     479           5776
# 3  2000       4  Indianapolis Colts   10     6     16     429           6141
# 4  2000       5   Minnesota Vikings   11     5     16     397           5961
#
#    Plays_Off  Y/P_Off  ...  Pen Yds_Def  1stPy_Def  Sc%_Def  TO%_Def  EXP_Def  \
# 0       1014      7.0  ...          747         31     40.9     12.4    21.56
# 1       1115      5.9  ...          898         25     30.2     20.8   104.83
# 2       1023      5.6  ...          912         33     26.9     18.7   185.58
# 3       1026      6.0  ...          820         24     31.1     11.7    64.32
# 4        958      6.2  ...          747         26     38.2      9.4     2.03
#
# ...

# %%
stats_df['PT_Result'] = (stats_df['PF_Off'] * stats_df['PF_Off']) / ((stats_df['PF_Off'] * stats_df['PF_Off']) + (stats_df['PF_Def'] * stats_df['PF_Def']))

# %%
stats_df.head()
# Out:
#    Year  Rk_Off                Team  Win  Loss  Games  PF_Off  Total Yds_Off  \
# 0  2000       1      St. Louis Rams   10     6     16     540           7075
# 1  2000       2      Denver Broncos   11     5     16     485           6554
# 2  2000       3     Oakland Raiders   12     4     16     479           5776
# 3  2000       4  Indianapolis Colts   10     6     16     429           6141
# 4  2000       5   Minnesota Vikings   11     5     16     397           5961
#
#    Plays_Off  Y/P_Off  ...  Pen Yds_Def  1stPy_Def  Sc%_Def  TO%_Def  EXP_Def  \
# 0       1014      7.0  ...          747         31     40.9     12.4    21.56
# 1       1115      5.9  ...          898         25     30.2     20.8   104.83
# 2       1023      5.6  ...          912         33     26.9     18.7   185.58
# 3       1026      6.0  ...          820         24     31.1     11.7    64.32
# 4        958      6.2  ...          747         26     38.2      9.4     2.03
#
# ...

# %%
#Write combined DataFrame to .csv
stats_df.to_csv("../Data/Team_Stats/2000-2019_cleaned_data4.csv",index=False)
